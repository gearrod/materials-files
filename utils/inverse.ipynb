# %%
from sklearn.decomposition import FastICA

# %%
from materials import *
from inverse import *
from direct import DIRECT_GRID_SILENT

# %%
INVERSE_GRID.fit(
    TRAIN_DATA[["p11", "p22", "p12"]],
    TRAIN_DATA[["angle", "ratio", "p_matrix", "p_fiber"]],
)

DIRECT_GRID_SILENT.fit(
    TRAIN_DATA[["angle", "ratio", "p_matrix", "p_fiber"]],
    TRAIN_DATA[["p11", "p22", "p12"]],
)
# Out:
# Fitting 5 folds for each of 107 candidates, totalling 535 fits
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7515.640, test=-7576.080) R2: (train=0.264, test=0.266) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7539.841, test=-7479.717) R2: (train=0.263, test=0.266) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7521.329, test=-7553.648) R2: (train=0.264, test=0.263) total time=   0.1s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7524.605, test=-7540.176) R2: (train=0.264, test=0.263) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7536.632, test=-7492.303) R2: (train=0.265, test=0.261) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6958.778, test=-6990.074) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6977.326, test=-6916.000) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6970.204, test=-6944.216) R2: (train=0.314, test=0.315) total time=   0.1s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6964.334, test=-6967.874) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.231, test=-7212.389) R2: (train=0.998, test=0.500) total time=   2.6s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-9.944, test=-7145.637) R2: (train=0.998, test=0.498) total time=   2.8s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-9.279, test=-7069.879) R2: (train=0.998, test=0.502) total time=   3.7s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.152, test=-7180.537) R2: (train=0.998, test=0.497) total time=   2.9s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7515.640, test=-7576.080) R2: (train=0.264, test=0.266) total time=   0.1s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7521.329, test=-7553.648) R2: (train=0.264, test=0.263) total time=   0.1s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.307, test=-7080.295) R2: (train=0.998, test=0.509) total time=   2.9s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7536.632, test=-7492.303) R2: (train=0.265, test=0.261) total time=   0.1s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7539.841, test=-7479.717) R2: (train=0.263, test=0.266) total time=   0.1s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7524.605, test=-7540.176) R2: (train=0.264, test=0.263) total time=   0.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.231, test=-7095.422) R2: (train=0.998, test=0.508) total time=   3.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.307, test=-6954.307) R2: (train=0.998, test=0.517) total time=   3.6s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-9.944, test=-6962.065) R2: (train=0.998, test=0.511) total time=   3.6s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.1s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6958.778, test=-6990.074) R2: (train=0.315, test=0.313) total time=   0.2s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6977.326, test=-6916.000) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6964.334, test=-6967.874) R2: (train=0.315, test=0.313) total time=   0.2s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6970.204, test=-6944.216) R2: (train=0.314, test=0.315) total time=   0.1s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-12.115, test=-7103.223) R2: (train=0.997, test=0.509) total time=   2.4s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-12.144, test=-7157.156) R2: (train=0.997, test=0.498) total time=   2.7s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-12.980, test=-7219.640) R2: (train=0.997, test=0.500) total time=   2.7s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.152, test=-6993.058) R2: (train=0.998, test=0.511) total time=   3.3s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-12.323, test=-7097.822) R2: (train=0.997, test=0.504) total time=   2.5s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-9.279, test=-6939.263) R2: (train=0.998, test=0.514) total time=   3.6s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7ff2107776a0>), regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.1s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7
#                                         DecisionTreeRegressor()]},
#                          {'preprocessing': [FunctionTransformer(func=<function <lambda> at 0x7fe...
#                           'preprocessing__n_components': [2, 3, 4],
#                           'regressor': [RandomForestRegressor()],
#                           'regressor__n_estimators': [5, 20, 50]},
#                          {'preprocessing': [FunctionTransformer(func=<function <lambda> at 0x7fe74c160180>)],
#                           'regressor': [RandomForestRegressor()],
#                           'regressor__n_estimators': [5, 20, 50]}],
#              refit='R2', return_train_score=True,
#              scoring={'MSE': make_scorer(mean_squared_error),
#                       'R2': make_scorer(r2_score)})

# %%
INVERSE_GRID.best_estimator_
# Out:
# Pipeline(steps=[('scaling', StandardScaler()),
#                 ('preprocessing', FastICA(n_components=3)),
#                 ('regressor', KNeighborsRegressor(n_neighbors=10))])

# %%
_, TRAIN_SAMPLES = train_test_split(TRAIN_DATA, test_size=200, random_state=13)
# TRAIN_SAMPLES=TRAIN_DATA

_, VALIDATION_SAMPLES = train_test_split(
    VALIDATION_DATA, test_size=200, random_state=13
)
# VALIDATION_SAMPLES=VALIDATION_DATA

# Draw graph with comparison of predicted vs AHM values for train and validation data
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 5), layout="constrained")

graph_p12 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
graph_p12.grid(True)
graph_p12.set_xscale("symlog", )
graph_p12.set_yscale("symlog", )

graph_p11 = plt.subplot2grid((2, 2), (1, 0))
graph_p11.grid(True)
graph_p11.set_xscale("symlog", )
graph_p11.set_yscale("symlog", )

graph_p22 = plt.subplot2grid((2, 2), (1, 1))
graph_p22.grid(True)
graph_p22.set_xscale("symlog", )
graph_p22.set_yscale("symlog", )


x_train, y_train = (TRAIN_SAMPLES), (
    DIRECT_GRID_SILENT.predict(
        INVERSE_GRID.best_estimator_.predict(TRAIN_SAMPLES[["p11", "p22", "p12"]])
    )
)

x_validation, y_validation = (VALIDATION_SAMPLES), (
    DIRECT_GRID_SILENT.predict(
        INVERSE_GRID.best_estimator_.predict(VALIDATION_SAMPLES[["p11", "p22", "p12"]])
    )
)

graph_p12.scatter(
    x_train["p12"],
    y_train[:, 2],
    color="red",
    label="Datos de entrenamiento",
)
graph_p12.scatter(
    x_validation["p12"],
    y_validation[:, 2],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p12.plot([-15, 5], [-15, 5], color="black")

# Limit x and y to the range between -40 and 10
graph_p12.set_xlim([-15, 5])
graph_p12.set_ylim([-15, 5])

graph_p11.scatter(
    x_train["p11"],
    y_train[:, 0],
    color="red",
    label="Datos de entrenamiento",
)
graph_p11.scatter(
    x_validation["p11"],
    y_validation[:, 0],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p11.plot([0, 1000], [0, 1000], color="black")

# Limit x and y to the range between 0 and 1000
graph_p11.set_xlim([0, 1000])
graph_p11.set_ylim([0, 1000])

graph_p22.scatter(
    x_train["p22"],
    y_train[:, 1],
    color="red",
    label="Datos de entrenamiento",
)
graph_p22.scatter(
    x_validation["p22"],
    y_validation[:, 1],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p22.plot([0, 1000], [0, 1000], color="black")

# Limit x and y to the range between 0 and 1000
graph_p22.set_xlim([0, 1000])
graph_p22.set_ylim([0, 1000])

plt.title(
    "Valores de entrada contra la aproximación del modelo directo sobre los valores de salida"
)

graph_p12.set_xlabel("Valores de entrada")
graph_p12.set_ylabel("Valores del modelo directo")
graph_p12.set_title("p12")

graph_p11.set_xlabel("Valores de homogenización")
graph_p11.set_ylabel("Valores del modelo directo")
graph_p11.set_title("p11")

graph_p22.set_xlabel("Valores de homogenización")
graph_p22.set_ylabel("Valores del modelo directo")
graph_p22.set_title("p22")

graph_p12.legend()
graph_p11.legend()
graph_p22.legend()

plt.show()
# Out:
# /home/gearrod/projects/thesis/materials-files/.env/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/gearrod/projects/thesis/materials-files/.env/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.preprocessing import StandardScaler

true = x_validation[["p11", "p22", "p12"]]
pred = y_validation

ss = StandardScaler().fit(true)
true = ss.transform(true)
pred = ss.transform(pred)

certain=np.linalg.norm(true - pred, axis=1)

np.mean(certain)
# Out:
# /home/gearrod/projects/thesis/materials-files/.env/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 0.10704645927280007

# %%
_, TRAIN_SAMPLES = train_test_split(TRAIN_DATA, test_size=200, random_state=13)
# TRAIN_SAMPLES=TRAIN_DATA

_, VALIDATION_SAMPLES = train_test_split(
    VALIDATION_DATA, test_size=200, random_state=13
)
# VALIDATION_SAMPLES=VALIDATION_DATA

# Draw graph with comparison of predicted vs AHM values for train and validation data
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6), layout="constrained")

graph_angle = plt.subplot2grid((2, 2), (0, 0))
graph_angle.grid(True)
# graph_angle.set_xscale("symlog", )
# graph_angle.set_yscale("symlog", )

graph_ratio = plt.subplot2grid((2, 2), (0, 1))
# graph_ratio.grid(True)
# graph_ratio.set_xscale("symlog", )
# graph_ratio.set_yscale("symlog", )

graph_p_matrix = plt.subplot2grid((2, 2), (1, 0))
# graph_p_matrix.grid(True)
# graph_p_matrix.set_xscale("symlog", )
# graph_p_matrix.set_yscale("symlog", )

graph_p_fiber = plt.subplot2grid((2, 2), (1, 1))
# graph_p_fiber.grid(True)
# graph_p_fiber.set_xscale("symlog", )
# graph_p_fiber.set_yscale("symlog", )


x_train, y_train = (TRAIN_SAMPLES), (
    INVERSE_GRID.predict(TRAIN_SAMPLES[["p11", "p22", "p12"]])
)

x_validation, y_validation = (VALIDATION_SAMPLES), (
    INVERSE_GRID.predict(VALIDATION_SAMPLES[["p11", "p22", "p12"]])
)

graph_angle.scatter(
    x_train["angle"],
    y_train[:, 0],
    color="red",
    label="Datos de entrenamiento",
)
graph_angle.scatter(
    x_validation["angle"],
    y_validation[:, 0],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_angle.plot([40, 90], [40, 90], color="black")

# Limit x and y to the range between -40 and 10
graph_angle.set_xlim([40, 90])
graph_angle.set_ylim([40, 90])

graph_ratio.scatter(
    x_train["ratio"],
    y_train[:, 1],
    color="red",
    label="Datos de entrenamiento",
)
graph_ratio.scatter(
    x_validation["ratio"],
    y_validation[:, 1],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_ratio.plot([0.0, 0.7], [0.0, 0.7], color="black")

# Limit x and y to the range between 0 and 1000
graph_ratio.set_xlim([0, 0.7])
graph_ratio.set_ylim([0, 0.7])

graph_p_matrix.scatter(
    x_train["p_matrix"],
    y_train[:, 2],
    color="red",
    label="Datos de entrenamiento",
)
graph_p_matrix.scatter(
    x_validation["p_matrix"],
    y_validation[:, 2],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p_matrix.plot([0, 500], [0, 500], color="black")

# Limit x and y to the range between 0 and 1000
graph_p_matrix.set_xlim([0, 500])
graph_p_matrix.set_ylim([0, 500])

graph_p_fiber.scatter(
    x_train["p_fiber"],
    y_train[:, 3],
    color="red",
    label="Datos de entrenamiento",
)
graph_p_fiber.scatter(
    x_validation["p_fiber"],
    y_validation[:, 3],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p_fiber.plot([0, 500], [0, 500], color="black")

# Limit x and y to the range between 0 and 1000
graph_p_fiber.set_xlim([0, 500])
graph_p_fiber.set_ylim([0, 500])


graph_angle.set_xlabel("Valores de homogenización")
graph_angle.set_ylabel("Valores estimados por KNN")
graph_angle.set_title("Valores estimados contra AHM para angle")

graph_ratio.set_xlabel("Valores de homogenización")
graph_ratio.set_ylabel("Valores estimados por KNN")
graph_ratio.set_title("Valores estimados contra AHM para ratio")

graph_p_matrix.set_xlabel("Valores de homogenización")
graph_p_matrix.set_ylabel("Valores estimados por KNN")
graph_p_matrix.set_title("Valores estimados contra AHM para p_matrix")

graph_p_fiber.set_xlabel("Valores de homogenización")
graph_p_fiber.set_ylabel("Valores estimados por KNN")
graph_p_fiber.set_title("Valores estimados contra AHM para p_fiber")

graph_angle.legend()
graph_ratio.legend()
graph_p_matrix.legend()
graph_p_fiber.legend()

plt.show()

# %%
[
    estimator.predict(TRAIN_DATA[["p11", "p22", "p12"]][69:70])
    for estimator in INVERSE_GRID.best_estimator_.steps[2][1].estimators_
]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 [
#       2     estimator.predict(TRAIN_DATA[["p11", "p22", "p12"]][69:70])
# ----> 3     for estimator in INVERSE_GRID.best_estimator_.steps[2][1].estimators_
#       4 ]
#
# AttributeError: 'KNeighborsRegressor' object has no attribute 'estimators_'

# %%
import pandas as pd

rows = [v for k, v in GRID.cv_results_.items() if k.startswith("split") and "_test_" in k and k.endswith("R2")]

df=pd.DataFrame(
    [list(row) for row in zip(*rows)],
    columns=["split" + str(i) for i in range(5)],
    index=[get_pipe_name(pipe) for pipe in GRID.cv_results_["params"]],
    dtype=float
)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 rows = [v for k, v in GRID.cv_results_.items() if k.startswith("split") and "_test_" in k and k.endswith("R2")]
#       5 df=pd.DataFrame(
#       6     [list(row) for row in zip(*rows)],
#       7     columns=["split" + str(i) for i in range(5)],
#       8     index=[get_pipe_name(pipe) for pipe in GRID.cv_results_["params"]],
#       9     dtype=float
#      10 )
#      12 df
#
# NameError: name 'GRID' is not defined

# %%
INVERSE_GRID.best_score_
# Out:
# 0.7099311079810912
