# %%
from sklearn.decomposition import FastICA

# %%
from materials import *
from inverse import *
from direct import DIRECT_GRID_SILENT

# %%
INVERSE_GRID.fit(
    TRAIN_DATA[["p11", "p22", "p12"]],
    TRAIN_DATA[["angle", "ratio", "p_matrix", "p_fiber"]],
)

DIRECT_GRID_SILENT.fit(
    TRAIN_DATA[["angle", "ratio", "p_matrix", "p_fiber"]],
    TRAIN_DATA[["p11", "p22", "p12"]],
)
# Out:
# Fitting 5 folds for each of 107 candidates, totalling 535 fits
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7536.632, test=-7492.303) R2: (train=0.265, test=0.261) total time=   0.1s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7515.640, test=-7576.080) R2: (train=0.264, test=0.266) total time=   0.1s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7521.329, test=-7553.648) R2: (train=0.264, test=0.263) total time=   0.1s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7539.841, test=-7479.717) R2: (train=0.263, test=0.266) total time=   0.1s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6958.778, test=-6990.074) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6977.326, test=-6916.000) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7524.605, test=-7540.176) R2: (train=0.264, test=0.263) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6970.204, test=-6944.216) R2: (train=0.314, test=0.315) total time=   0.0s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6964.334, test=-6967.874) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-9.944, test=-7137.174) R2: (train=0.998, test=0.498) total time=   1.0s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-9.279, test=-7122.161) R2: (train=0.998, test=0.501) total time=   1.0s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.307, test=-7085.339) R2: (train=0.998, test=0.510) total time=   1.1s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.152, test=-7188.906) R2: (train=0.998, test=0.498) total time=   1.1s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7515.640, test=-7576.080) R2: (train=0.264, test=0.266) total time=   0.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.231, test=-7252.762) R2: (train=0.998, test=0.498) total time=   1.0s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7521.329, test=-7553.648) R2: (train=0.264, test=0.263) total time=   0.0s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7536.632, test=-7492.303) R2: (train=0.265, test=0.261) total time=   0.0s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7539.841, test=-7479.717) R2: (train=0.263, test=0.266) total time=   0.0s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7524.605, test=-7540.176) R2: (train=0.264, test=0.263) total time=   0.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.231, test=-7069.642) R2: (train=0.998, test=0.509) total time=   1.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.307, test=-6930.671) R2: (train=0.998, test=0.518) total time=   1.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-9.944, test=-6987.005) R2: (train=0.998, test=0.509) total time=   1.3s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.0s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6958.778, test=-6990.074) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6977.326, test=-6916.000) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6964.334, test=-6967.874) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6970.204, test=-6944.216) R2: (train=0.314, test=0.315) total time=   0.1s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.152, test=-6999.380) R2: (train=0.998, test=0.511) total time=   1.1s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-9.279, test=-6963.633) R2: (train=0.998, test=0.513) total time=   1.2s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-12.551, test=-7138.997) R2: (train=0.997, test=0.508) total time=   0.9s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-12.478, test=-7204.475) R2: (train=0.997, test=0.500) total time=   0.9s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-11.315, test=-7108.245) R2: (train=0.997, test=0.500) total time=   1.0s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f7090f076a0>), regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.0s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f7090f076a0>), regressor=LinearRegression(); MSE: (train=-6958.778, test=-6990.074) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f708bd816c0>), regressor=LinearRegression(); MSE: (train=-6977.326, test=-6916.000) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f708bd816c0>), regressor=LinearRegression(); MSE: (train=-6964.334, test=-6967.874) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-11.115, test=-7041.558) R2: (train=0.997, test=0.507) total time=   1.0s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f7091a3c7c0>), regressor=LinearRegression(); MSE: (train=-6970.204, test=-6944.216) R2: (train=0.314, test=0.315) total time=   0.0s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-12.521, test=-7120.019) R2: (train=0.997, test=0.499) total time=   1.0s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-12.331, test=-6755.576) R2: (train=0.997, test=0.524) total time=   1.2s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-11.916, test=-6771.600) R2: (train=0.997, test=0.520) total time=   1.2s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-12.262, test=-6717.999) R2: (train=0.997, test=0.530) total time=   1.4s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-11.341, test=-6754.089) R2: (train=0.997, test=0.524) total time=   1.3s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-11.217, test=-6852.043) R2: (train=0.997, test=0.517) total time=   1.4s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f7091a3c7c0>), regressor=DecisionTreeRegressor(); MSE: (train=-10.763, test=-7164.414) R2: (train=0.997, test=0.504) total time=   1.1s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fdd2a4176a0>), regressor=DecisionTreeRegressor(); MSE: (train=-12.347, test=-7129.707) R2: (train=0.997, test=0.513) total time=   1.3s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f2135eee0c0>), regressor=DecisionTreeRegressor(); MSE: (train=-11.313, test=-7154.446) R2: (train=0.998, test=0.509) total time=   1.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2901.191, test=-4375.849) R2: (train=0.795, test=0.696) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2882.091, test=-4393.761) R2: (train=0.798, test=0.688) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2872.332, test=-4425.763) R2: (train=0.797, test=0.690) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2884.668, test=-4392.598) R2: (train=0.797, test=0.692) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2868.787, test=-4424.525) R2: (train=0.797, test=0.691) total time=   0.2s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fa8dc6142c0>), regressor=DecisionTreeRegressor(); MSE: (train=-10.752, test=-7144.170) R2: (train=0.997, test=0.507) total time=   1.1s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4821.962) R2: (train=1.000, test=0.658) total time=   0.2s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f3f5bb107c0>), regressor=DecisionTreeRegressor(); MSE: (train=-9.884, test=-7053.055) R2: (train=0.997, test=0.512) total time=   1.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4841.225) R2: (train=1.000, test=0.651) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4922.429) R2: (train=1.000, test=0.651) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4869.168) R2: (train=1.000, test=0.651) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4886.447) R2: (train=1.000, test=0.652) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3061.357, test=-4339.795) R2: (train=0.786, test=0.693) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3061.209, test=-4343.429) R2: (train=0.785, test=0.699) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3054.840, test=-4330.150) R2: (train=0.786, test=0.697) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3044.906, test=-4359.591) R2: (train=0.786, test=0.696) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3038.480, test=-4362.019) R2: (train=0.786, test=0.696) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4772.852) R2: (train=1.000, test=0.656) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4767.146) R2: (train=1.000, test=0.663) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4847.399) R2: (train=1.000, test=0.657) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4798.493) R2: (train=1.000, test=0.657) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4815.275) R2: (train=1.000, test=0.658) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3201.211, test=-4320.611) R2: (train=0.776, test=0.702) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3199.984, test=-4306.151) R2: (train=0.777, test=0.695) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3186.028, test=-4343.941) R2: (train=0.777, test=0.698) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3191.515, test=-4307.841) R2: (train=0.777, test=0.700) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3186.618, test=-4352.034) R2: (train=0.777, test=0.698) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4722.200) R2: (train=1.000, test=0.660) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4726.994) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4754.378) R2: (train=1.000, test=0.661) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4801.951) R2: (train=1.000, test=0.660) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4776.893) R2: (train=1.000, test=0.662) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3321.603, test=-4323.291) R2: (train=0.768, test=0.703) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3309.202, test=-4310.580) R2: (train=0.769, test=0.700) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3306.500, test=-4336.362) R2: (train=0.770, test=0.700) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3302.544, test=-4340.063) R2: (train=0.770, test=0.700) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3321.152, test=-4310.248) R2: (train=0.770, test=0.696) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4701.734) R2: (train=1.000, test=0.669) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4773.087) R2: (train=1.000, test=0.663) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4699.008) R2: (train=1.000, test=0.662) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4724.801) R2: (train=1.000, test=0.664) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4743.022) R2: (train=1.000, test=0.665) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3420.532, test=-4340.253) R2: (train=0.762, test=0.704) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3422.615, test=-4308.900) R2: (train=0.764, test=0.697) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3405.276, test=-4351.227) R2: (train=0.763, test=0.700) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3407.507, test=-4329.775) R2: (train=0.763, test=0.701) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4691.968) R2: (train=1.000, test=0.671) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3413.167, test=-4321.846) R2: (train=0.763, test=0.701) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4755.227) R2: (train=1.000, test=0.665) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4704.824) R2: (train=1.000, test=0.666) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4674.683) R2: (train=1.000, test=0.664) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4719.325) R2: (train=1.000, test=0.667) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3507.584, test=-4333.216) R2: (train=0.757, test=0.705) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3512.540, test=-4319.771) R2: (train=0.758, test=0.697) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3495.206, test=-4362.519) R2: (train=0.758, test=0.700) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3501.831, test=-4327.186) R2: (train=0.758, test=0.701) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4670.890) R2: (train=1.000, test=0.673) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4658.274) R2: (train=1.000, test=0.666) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4741.331) R2: (train=1.000, test=0.666) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3497.934, test=-4337.257) R2: (train=0.758, test=0.702) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4683.804) R2: (train=1.000, test=0.668) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3586.693, test=-4348.011) R2: (train=0.752, test=0.705) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4703.397) R2: (train=1.000, test=0.668) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3587.907, test=-4339.728) R2: (train=0.753, test=0.697) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3576.332, test=-4383.152) R2: (train=0.753, test=0.699) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3582.778, test=-4354.193) R2: (train=0.753, test=0.702) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4648.648) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4660.927) R2: (train=1.000, test=0.674) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3586.617, test=-4345.510) R2: (train=0.753, test=0.701) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4730.655) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4693.088) R2: (train=1.000, test=0.670) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4670.099) R2: (train=1.000, test=0.669) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3663.990, test=-4374.956) R2: (train=0.747, test=0.704) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3662.372, test=-4365.025) R2: (train=0.749, test=0.696) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3648.543, test=-4411.129) R2: (train=0.749, test=0.699) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3658.854, test=-4365.800) R2: (train=0.749, test=0.700) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3658.074, test=-4375.110) R2: (train=0.748, test=0.701) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4640.408) R2: (train=1.000, test=0.668) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4655.253) R2: (train=1.000, test=0.675) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4723.484) R2: (train=1.000, test=0.668) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4661.736) R2: (train=1.000, test=0.670) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4682.763) R2: (train=1.000, test=0.671) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3735.497, test=-4387.747) R2: (train=0.745, test=0.695) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3732.385, test=-4398.094) R2: (train=0.743, test=0.703) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3731.013, test=-4394.719) R2: (train=0.744, test=0.699) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3719.221, test=-4427.372) R2: (train=0.745, test=0.698) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3728.138, test=-4398.500) R2: (train=0.744, test=0.700) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4635.019) R2: (train=1.000, test=0.669) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4646.679) R2: (train=1.000, test=0.676) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4716.241) R2: (train=1.000, test=0.669) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4655.875) R2: (train=1.000, test=0.670) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2900.471, test=-4376.455) R2: (train=0.795, test=0.696) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2881.109, test=-4391.805) R2: (train=0.798, test=0.688) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4676.549) R2: (train=1.000, test=0.671) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2870.306, test=-4425.562) R2: (train=0.797, test=0.690) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2884.021, test=-4390.003) R2: (train=0.797, test=0.692) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2868.411, test=-4421.621) R2: (train=0.797, test=0.691) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4821.681) R2: (train=1.000, test=0.659) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4840.670) R2: (train=1.000, test=0.651) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4922.729) R2: (train=1.000, test=0.651) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4864.814) R2: (train=1.000, test=0.652) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4883.908) R2: (train=1.000, test=0.652) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3060.305, test=-4343.459) R2: (train=0.785, test=0.699) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3060.321, test=-4338.752) R2: (train=0.786, test=0.693) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3053.916, test=-4328.435) R2: (train=0.786, test=0.697) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3037.362, test=-4360.290) R2: (train=0.786, test=0.696) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4767.235) R2: (train=1.000, test=0.663) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4772.994) R2: (train=1.000, test=0.656) total time=   0.2s[CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3044.277, test=-4357.927) R2: (train=0.786, test=0.696) total time=   0.3s
#
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4846.281) R2: (train=1.000, test=0.657) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4795.992) R2: (train=1.000, test=0.658) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4813.692) R2: (train=1.000, test=0.658) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3200.116, test=-4319.359) R2: (train=0.776, test=0.702) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3185.000, test=-4343.468) R2: (train=0.777, test=0.698) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3199.155, test=-4305.438) R2: (train=0.777, test=0.695) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3190.538, test=-4305.918) R2: (train=0.777, test=0.700) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3185.556, test=-4350.263) R2: (train=0.777, test=0.698) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4726.261) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4723.103) R2: (train=1.000, test=0.660) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4801.775) R2: (train=1.000, test=0.660) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4751.421) R2: (train=1.000, test=0.661) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4775.639) R2: (train=1.000, test=0.662) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3321.110, test=-4322.835) R2: (train=0.768, test=0.703) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3319.880, test=-4310.393) R2: (train=0.770, test=0.696) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3308.556, test=-4310.648) R2: (train=0.769, test=0.700) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4701.755) R2: (train=1.000, test=0.669) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3305.678, test=-4335.924) R2: (train=0.770, test=0.700) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3301.900, test=-4339.829) R2: (train=0.770, test=0.700) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4699.774) R2: (train=1.000, test=0.662) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4773.578) R2: (train=1.000, test=0.663) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4722.992) R2: (train=1.000, test=0.664) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4742.703) R2: (train=1.000, test=0.665) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3422.019, test=-4308.366) R2: (train=0.764, test=0.697) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3420.011, test=-4338.540) R2: (train=0.762, test=0.704) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3404.042, test=-4348.325) R2: (train=0.763, test=0.700) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3411.848, test=-4320.866) R2: (train=0.763, test=0.701) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3407.108, test=-4328.819) R2: (train=0.763, test=0.701) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4675.022) R2: (train=1.000, test=0.664) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4690.917) R2: (train=1.000, test=0.671) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4754.668) R2: (train=1.000, test=0.665) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4702.487) R2: (train=1.000, test=0.666) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4718.723) R2: (train=1.000, test=0.667) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3494.649, test=-4362.265) R2: (train=0.758, test=0.700) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3511.451, test=-4318.374) R2: (train=0.758, test=0.698) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3506.916, test=-4331.947) R2: (train=0.757, test=0.705) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3501.008, test=-4327.278) R2: (train=0.758, test=0.701) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3497.055, test=-4336.659) R2: (train=0.758, test=0.702) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4670.183) R2: (train=1.000, test=0.673) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4658.108) R2: (train=1.000, test=0.666) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4741.867) R2: (train=1.000, test=0.666) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4682.164) R2: (train=1.000, test=0.668) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4702.532) R2: (train=1.000, test=0.668) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3587.377, test=-4339.470) R2: (train=0.753, test=0.697) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3585.826, test=-4348.221) R2: (train=0.752, test=0.705) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3575.937, test=-4382.841) R2: (train=0.753, test=0.699) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3582.286, test=-4352.857) R2: (train=0.753, test=0.702) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3586.201, test=-4344.927) R2: (train=0.753, test=0.701) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4731.224) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4661.146) R2: (train=1.000, test=0.674) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4648.684) R2: (train=1.000, test=0.667) total time=   0.5s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4668.118) R2: (train=1.000, test=0.669) total time=   0.4s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4692.057) R2: (train=1.000, test=0.670) total time=   0.3s
# ...
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-768.932, test=-5038.224) R2: (train=0.945, test=0.645) total time=  15.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1050.990, test=-5239.096) R2: (train=0.925, test=0.640) total time=   4.5s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1048.567, test=-5244.087) R2: (train=0.926, test=0.628) total time=   4.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1044.306, test=-5350.496) R2: (train=0.926, test=0.628) total time=   4.6s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1041.040, test=-5303.374) R2: (train=0.926, test=0.630) total time=   3.8s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1055.026, test=-5351.069) R2: (train=0.926, test=0.625) total time=   4.4s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-713.460, test=-4937.647) R2: (train=0.949, test=0.658) total time=  35.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-708.177, test=-4964.286) R2: (train=0.949, test=0.649) total time=  36.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-757.177, test=-4960.555) R2: (train=0.946, test=0.650) total time=  15.6s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-707.159, test=-5019.740) R2: (train=0.949, test=0.650) total time=  36.6s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-760.675, test=-4896.746) R2: (train=0.945, test=0.659) total time=  18.7s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-755.465, test=-4993.836) R2: (train=0.946, test=0.652) total time=  17.7s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-707.721, test=-4955.842) R2: (train=0.949, test=0.651) total time=  33.6s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-707.728, test=-5010.854) R2: (train=0.949, test=0.648) total time=  32.7s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1062.734, test=-5306.189) R2: (train=0.924, test=0.632) total time=   3.9s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1063.823, test=-5368.088) R2: (train=0.925, test=0.620) total time=   4.1s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-750.039, test=-4965.876) R2: (train=0.946, test=0.651) total time=  19.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-753.564, test=-5009.762) R2: (train=0.946, test=0.649) total time=  18.7s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1061.065, test=-5435.405) R2: (train=0.925, test=0.623) total time=   4.1s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1061.836, test=-5374.175) R2: (train=0.924, test=0.623) total time=   3.6s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1070.575, test=-5414.775) R2: (train=0.924, test=0.621) total time=   3.8s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-769.361, test=-4975.313) R2: (train=0.945, test=0.654) total time=  12.9s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-769.753, test=-4990.141) R2: (train=0.945, test=0.646) total time=  15.8s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-759.978, test=-5044.408) R2: (train=0.945, test=0.648) total time=  15.6s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-699.998, test=-4848.229) R2: (train=0.949, test=0.663) total time=  45.4s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-697.736, test=-4927.308) R2: (train=0.950, test=0.656) total time=  45.4s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-699.634, test=-4870.806) R2: (train=0.950, test=0.655) total time=  49.7s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-765.239, test=-5014.819) R2: (train=0.945, test=0.648) total time=  15.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-697.814, test=-4913.991) R2: (train=0.950, test=0.655) total time=  46.5s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-792.898, test=-5203.911) R2: (train=0.942, test=0.630) total time=  12.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-693.066, test=-4933.048) R2: (train=0.950, test=0.654) total time=  47.7s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1009.110, test=-5071.079) R2: (train=0.927, test=0.644) total time=   4.4s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1015.332, test=-5147.411) R2: (train=0.928, test=0.634) total time=   4.8s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1012.472, test=-5167.921) R2: (train=0.927, test=0.638) total time=   4.6s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1008.072, test=-5191.326) R2: (train=0.927, test=0.635) total time=   4.9s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1014.171, test=-5205.053) R2: (train=0.927, test=0.633) total time=   5.1s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-711.731, test=-4896.493) R2: (train=0.949, test=0.659) total time=  32.4s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-734.851, test=-4841.430) R2: (train=0.947, test=0.655) total time=  19.0s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-708.520, test=-4929.410) R2: (train=0.949, test=0.650) total time=  32.9s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-738.174, test=-4772.912) R2: (train=0.946, test=0.666) total time=  20.9s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-733.931, test=-4831.867) R2: (train=0.947, test=0.660) total time=  21.9s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-706.749, test=-4978.715) R2: (train=0.949, test=0.653) total time=  37.5s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-706.747, test=-4949.929) R2: (train=0.949, test=0.651) total time=  35.3s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-705.767, test=-4992.163) R2: (train=0.949, test=0.649) total time=  37.2s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-734.589, test=-4822.636) R2: (train=0.947, test=0.658) total time=  19.2s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f2132f1c180>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1060.591, test=-5305.837) R2: (train=0.925, test=0.638) total time=   4.9s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f3f5bb107c0>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1060.967, test=-5369.982) R2: (train=0.926, test=0.625) total time=   5.6s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-731.128, test=-4863.966) R2: (train=0.947, test=0.656) total time=  18.5s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f2132f1c180>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1065.030, test=-5341.034) R2: (train=0.925, test=0.630) total time=   5.4s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f3f5bb107c0>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1067.898, test=-5308.297) R2: (train=0.925, test=0.631) total time=   4.9s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f3236c13100>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1046.554, test=-5333.372) R2: (train=0.926, test=0.629) total time=   4.8s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f2132f1c180>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-770.305, test=-5005.096) R2: (train=0.945, test=0.656) total time=  18.7s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f3f5bb107c0>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-763.397, test=-5005.687) R2: (train=0.946, test=0.647) total time=  18.1s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f3236c13100>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-764.751, test=-5037.182) R2: (train=0.946, test=0.652) total time=  18.1s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-676.261, test=-4784.534) R2: (train=0.951, test=0.663) total time=  46.4s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-683.248, test=-4706.627) R2: (train=0.950, test=0.670) total time=  51.9s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-676.283, test=-4764.119) R2: (train=0.951, test=0.660) total time=  52.9s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-673.544, test=-4808.399) R2: (train=0.951, test=0.660) total time=  50.5s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-680.630, test=-4803.617) R2: (train=0.951, test=0.661) total time=  51.8s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f2132f1c180>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-767.726, test=-4978.999) R2: (train=0.946, test=0.652) total time=  19.7s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f3f5baf76a0>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-766.358, test=-5042.079) R2: (train=0.946, test=0.650) total time=  19.3s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f3236e20180>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-710.792, test=-4922.500) R2: (train=0.949, test=0.661) total time=  39.4s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fb3149b36a0>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-704.532, test=-4934.170) R2: (train=0.950, test=0.654) total time=  34.0s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fdd2164f560>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-706.033, test=-4984.692) R2: (train=0.950, test=0.655) total time=  35.8s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fa8dc43c860>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-708.443, test=-4925.920) R2: (train=0.950, test=0.657) total time=  35.7s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f708bda60c0>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-701.890, test=-4963.428) R2: (train=0.950, test=0.654) total time=  32.6s
# GridSearchCV(estimator=Pipeline(steps=[('scaling', StandardScaler()),
#                                        ('preprocessing', 'passthrough'),
#                                        ('regressor', 'passthrough')]),
#              n_jobs=-1,
#              param_grid=[{'preprocessing': [PCA(), FastICA()],
#                           'preprocessing__n_components': [2, 3, 4],
#                           'regressor': [LinearRegression(),
#                                         DecisionTreeRegressor()]},
#                          {'preprocessing': [FunctionTransformer(func=<function <lambda> at 0x7fb...
#                           'preprocessing__n_components': [2, 3, 4],
#                           'regressor': [RandomForestRegressor()],
#                           'regressor__n_estimators': [5, 20, 50]},
#                          {'preprocessing': [FunctionTransformer(func=<function <lambda> at 0x7fbebe6580e0>)],
#                           'regressor': [RandomForestRegressor()],
#                           'regressor__n_estimators': [5, 20, 50]}],
#              refit='R2', return_train_score=True,
#              scoring={'MSE': make_scorer(mean_squared_error),
#                       'R2': make_scorer(r2_score)})

# %%
INVERSE_GRID.best_estimator_
# Out:
# Pipeline(steps=[('scaling', StandardScaler()),
#                 ('preprocessing', FastICA(n_components=3)),
#                 ('regressor', KNeighborsRegressor(n_neighbors=10))])

# %%
_, TRAIN_SAMPLES = train_test_split(TRAIN_DATA, test_size=200, random_state=50)
# TRAIN_SAMPLES=TRAIN_DATA

_, VALIDATION_SAMPLES = train_test_split(
    VALIDATION_DATA, test_size=200, random_state=50
)
# VALIDATION_SAMPLES=VALIDATION_DATA

# Draw graph with comparison of predicted vs AHM values for train and validation data
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(8, 5), layout="constrained")

graph_p12 = plt.subplot2grid((2, 2), (0, 0), colspan=2)
graph_p12.grid(True)
graph_p12.set_xscale("symlog", )
graph_p12.set_yscale("symlog", )

graph_p11 = plt.subplot2grid((2, 2), (1, 0))
graph_p11.grid(True)
graph_p11.set_xscale("symlog", )
graph_p11.set_yscale("symlog", )

graph_p22 = plt.subplot2grid((2, 2), (1, 1))
graph_p22.grid(True)
graph_p22.set_xscale("symlog", )
graph_p22.set_yscale("symlog", )


x_train, y_train = (TRAIN_SAMPLES), (
    DIRECT_GRID_SILENT.predict(
        INVERSE_GRID.best_estimator_.predict(TRAIN_SAMPLES[["p11", "p22", "p12"]])
    )
)

x_validation, y_validation = (VALIDATION_SAMPLES), (
    DIRECT_GRID_SILENT.predict(
        INVERSE_GRID.best_estimator_.predict(VALIDATION_SAMPLES[["p11", "p22", "p12"]])
    )
)

graph_p12.scatter(
    x_train["p12"],
    y_train[:, 2],
    color="red",
    label="Datos de entrenamiento",
)
graph_p12.scatter(
    x_validation["p12"],
    y_validation[:, 2],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p12.plot([-15, 5], [-15, 5], color="black")

# Limit x and y to the range between -40 and 10
graph_p12.set_xlim([-15, 5])
graph_p12.set_ylim([-15, 5])

graph_p11.scatter(
    x_train["p11"],
    y_train[:, 0],
    color="red",
    label="Datos de entrenamiento",
)
graph_p11.scatter(
    x_validation["p11"],
    y_validation[:, 0],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p11.plot([0, 1000], [0, 1000], color="black")

# Limit x and y to the range between 0 and 1000
graph_p11.set_xlim([0, 1000])
graph_p11.set_ylim([0, 1000])

graph_p22.scatter(
    x_train["p22"],
    y_train[:, 1],
    color="red",
    label="Datos de entrenamiento",
)
graph_p22.scatter(
    x_validation["p22"],
    y_validation[:, 1],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p22.plot([0, 1000], [0, 1000], color="black")

# Limit x and y to the range between 0 and 1000
graph_p22.set_xlim([0, 1000])
graph_p22.set_ylim([0, 1000])

plt.title(
    "Valores de entrada contra la aproximación del modelo directo sobre los valores de salida"
)

graph_p12.set_xlabel("Valores de entrada")
graph_p12.set_ylabel("Valores del modelo directo")
graph_p12.set_title("p12")

graph_p11.set_xlabel("Valores de homogenización")
graph_p11.set_ylabel("Valores del modelo directo")
graph_p11.set_title("p11")

graph_p22.set_xlabel("Valores de homogenización")
graph_p22.set_ylabel("Valores del modelo directo")
graph_p22.set_title("p22")

graph_p12.legend()
graph_p11.legend()
graph_p22.legend()

plt.show()
# Out:
# /home/gearrod/projects/thesis/materials-files/.env/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# /home/gearrod/projects/thesis/materials-files/.env/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.preprocessing import StandardScaler

true = x_validation[["p11", "p22", "p12"]]
pred = y_validation

ss = StandardScaler().fit(true)
true = ss.transform(true)
pred = ss.transform(pred)

certain=np.linalg.norm(true - pred, axis=1)

np.mean(certain)
# Out:
# /home/gearrod/projects/thesis/materials-files/.env/lib/python3.11/site-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
# 0.09827513142472694

# %%
_, TRAIN_SAMPLES = train_test_split(TRAIN_DATA, test_size=200, random_state=50)
# TRAIN_SAMPLES=TRAIN_DATA

_, VALIDATION_SAMPLES = train_test_split(
    VALIDATION_DATA, test_size=200, random_state=50
)
# VALIDATION_SAMPLES=VALIDATION_DATA

# Draw graph with comparison of predicted vs AHM values for train and validation data
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6), layout="constrained")

graph_angle = plt.subplot2grid((2, 2), (0, 0))
graph_angle.grid(True)
# graph_angle.set_xscale("symlog", )
# graph_angle.set_yscale("symlog", )

graph_ratio = plt.subplot2grid((2, 2), (0, 1))
# graph_ratio.grid(True)
# graph_ratio.set_xscale("symlog", )
# graph_ratio.set_yscale("symlog", )

graph_p_matrix = plt.subplot2grid((2, 2), (1, 0))
# graph_p_matrix.grid(True)
# graph_p_matrix.set_xscale("symlog", )
# graph_p_matrix.set_yscale("symlog", )

graph_p_fiber = plt.subplot2grid((2, 2), (1, 1))
# graph_p_fiber.grid(True)
# graph_p_fiber.set_xscale("symlog", )
# graph_p_fiber.set_yscale("symlog", )


x_train, y_train = (TRAIN_SAMPLES), (
    INVERSE_GRID.predict(TRAIN_SAMPLES[["p11", "p22", "p12"]])
)

x_validation, y_validation = (VALIDATION_SAMPLES), (
    INVERSE_GRID.predict(VALIDATION_SAMPLES[["p11", "p22", "p12"]])
)

graph_angle.scatter(
    x_train["angle"],
    y_train[:, 0],
    color="red",
    label="Datos de entrenamiento",
)
graph_angle.scatter(
    x_validation["angle"],
    y_validation[:, 0],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_angle.plot([40, 90], [40, 90], color="black")

# Limit x and y to the range between -40 and 10
graph_angle.set_xlim([40, 90])
graph_angle.set_ylim([40, 90])

graph_ratio.scatter(
    x_train["ratio"],
    y_train[:, 1],
    color="red",
    label="Datos de entrenamiento",
)
graph_ratio.scatter(
    x_validation["ratio"],
    y_validation[:, 1],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_ratio.plot([0.0, 0.7], [0.0, 0.7], color="black")

# Limit x and y to the range between 0 and 1000
graph_ratio.set_xlim([0, 0.7])
graph_ratio.set_ylim([0, 0.7])

graph_p_matrix.scatter(
    x_train["p_matrix"],
    y_train[:, 2],
    color="red",
    label="Datos de entrenamiento",
)
graph_p_matrix.scatter(
    x_validation["p_matrix"],
    y_validation[:, 2],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p_matrix.plot([0, 500], [0, 500], color="black")

# Limit x and y to the range between 0 and 1000
graph_p_matrix.set_xlim([0, 500])
graph_p_matrix.set_ylim([0, 500])

graph_p_fiber.scatter(
    x_train["p_fiber"],
    y_train[:, 3],
    color="red",
    label="Datos de entrenamiento",
)
graph_p_fiber.scatter(
    x_validation["p_fiber"],
    y_validation[:, 3],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p_fiber.plot([0, 500], [0, 500], color="black")

# Limit x and y to the range between 0 and 1000
graph_p_fiber.set_xlim([0, 500])
graph_p_fiber.set_ylim([0, 500])


graph_angle.set_xlabel("Valores de homogenización")
graph_angle.set_ylabel("Valores estimados por KNN")
graph_angle.set_title("Valores estimados contra AHM para angle")

graph_ratio.set_xlabel("Valores de homogenización")
graph_ratio.set_ylabel("Valores estimados por KNN")
graph_ratio.set_title("Valores estimados contra AHM para ratio")

graph_p_matrix.set_xlabel("Valores de homogenización")
graph_p_matrix.set_ylabel("Valores estimados por KNN")
graph_p_matrix.set_title("Valores estimados contra AHM para p_matrix")

graph_p_fiber.set_xlabel("Valores de homogenización")
graph_p_fiber.set_ylabel("Valores estimados por KNN")
graph_p_fiber.set_title("Valores estimados contra AHM para p_fiber")

graph_angle.legend()
graph_ratio.legend()
graph_p_matrix.legend()
graph_p_fiber.legend()

plt.show()

# %%
[
    estimator.predict(TRAIN_DATA[["p11", "p22", "p12"]][69:70])
    for estimator in INVERSE_GRID.best_estimator_.steps[2][1].estimators_
]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 3
#       1 [
#       2     estimator.predict(TRAIN_DATA[["p11", "p22", "p12"]][69:70])
# ----> 3     for estimator in INVERSE_GRID.best_estimator_.steps[2][1].estimators_
#       4 ]
#
# AttributeError: 'KNeighborsRegressor' object has no attribute 'estimators_'

# %%
import pandas as pd

rows = [v for k, v in GRID.cv_results_.items() if k.startswith("split") and "_test_" in k and k.endswith("R2")]

df=pd.DataFrame(
    [list(row) for row in zip(*rows)],
    columns=["split" + str(i) for i in range(5)],
    index=[get_pipe_name(pipe) for pipe in GRID.cv_results_["params"]],
    dtype=float
)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 rows = [v for k, v in GRID.cv_results_.items() if k.startswith("split") and "_test_" in k and k.endswith("R2")]
#       5 df=pd.DataFrame(
#       6     [list(row) for row in zip(*rows)],
#       7     columns=["split" + str(i) for i in range(5)],
#       8     index=[get_pipe_name(pipe) for pipe in GRID.cv_results_["params"]],
#       9     dtype=float
#      10 )
#      12 df
#
# NameError: name 'GRID' is not defined

# %%
INVERSE_GRID.best_score_
# Out:
# 0.7099311079810912
