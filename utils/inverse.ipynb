# %%
from sklearn.decomposition import FastICA

# %%
from materials import *
from inverse import *

# %%
INVERSE_GRID.fit(
    TRAIN_DATA[["p11", "p22", "p12"]],
    TRAIN_DATA[["angle", "ratio", "p_matrix", "p_fiber"]])
# Out:
# Fitting 5 folds for each of 107 candidates, totalling 535 fits
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7524.605, test=-7540.176) R2: (train=0.264, test=0.263) total time=   0.1s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7521.329, test=-7553.648) R2: (train=0.264, test=0.263) total time=   0.1s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7515.640, test=-7576.080) R2: (train=0.264, test=0.266) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7539.841, test=-7479.717) R2: (train=0.263, test=0.266) total time=   0.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7536.632, test=-7492.303) R2: (train=0.265, test=0.261) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.1s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6958.778, test=-6990.074) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6977.326, test=-6916.000) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6964.334, test=-6967.874) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6970.204, test=-6944.216) R2: (train=0.314, test=0.315) total time=   0.1s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-9.279, test=-7080.090) R2: (train=0.998, test=0.501) total time=   1.1s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-9.944, test=-7143.831) R2: (train=0.998, test=0.497) total time=   1.1s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.307, test=-7115.773) R2: (train=0.998, test=0.508) total time=   1.1s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.231, test=-7213.969) R2: (train=0.998, test=0.500) total time=   0.9s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-10.152, test=-7161.769) R2: (train=0.998, test=0.498) total time=   1.1s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7515.640, test=-7576.080) R2: (train=0.264, test=0.266) total time=   0.0s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7521.329, test=-7553.648) R2: (train=0.264, test=0.263) total time=   0.0s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7536.632, test=-7492.303) R2: (train=0.265, test=0.261) total time=   0.0s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7539.841, test=-7479.717) R2: (train=0.263, test=0.266) total time=   0.0s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=LinearRegression(); MSE: (train=-7524.605, test=-7540.176) R2: (train=0.264, test=0.263) total time=   0.0s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.307, test=-6927.938) R2: (train=0.998, test=0.519) total time=   1.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.231, test=-7100.473) R2: (train=0.998, test=0.508) total time=   1.4s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-9.944, test=-6953.326) R2: (train=0.998, test=0.511) total time=   1.6s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.1s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6958.778, test=-6990.074) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6977.326, test=-6916.000) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6964.334, test=-6967.874) R2: (train=0.315, test=0.313) total time=   0.1s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=LinearRegression(); MSE: (train=-6970.204, test=-6944.216) R2: (train=0.314, test=0.315) total time=   0.0s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-12.625, test=-7072.917) R2: (train=0.997, test=0.508) total time=   0.8s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-11.773, test=-7089.170) R2: (train=0.997, test=0.501) total time=   0.8s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-10.152, test=-7031.115) R2: (train=0.998, test=0.509) total time=   1.2s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-11.818, test=-7141.229) R2: (train=0.997, test=0.504) total time=   0.9s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-9.279, test=-6993.445) R2: (train=0.998, test=0.512) total time=   1.3s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f834aba36a0>), regressor=LinearRegression(); MSE: (train=-6954.065, test=-7008.771) R2: (train=0.314, test=0.317) total time=   0.0s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f834aba36a0>), regressor=LinearRegression(); MSE: (train=-6958.778, test=-6990.074) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f834aba36a0>), regressor=LinearRegression(); MSE: (train=-6977.326, test=-6916.000) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f834aba36a0>), regressor=LinearRegression(); MSE: (train=-6964.334, test=-6967.874) R2: (train=0.315, test=0.313) total time=   0.0s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-11.701, test=-7135.947) R2: (train=0.997, test=0.502) total time=   1.0s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f83454a96c0>), regressor=LinearRegression(); MSE: (train=-6970.204, test=-6944.216) R2: (train=0.314, test=0.315) total time=   0.0s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=DecisionTreeRegressor(); MSE: (train=-11.903, test=-7087.206) R2: (train=0.997, test=0.502) total time=   1.0s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-11.832, test=-6841.071) R2: (train=0.997, test=0.522) total time=   1.2s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-12.539, test=-6699.331) R2: (train=0.997, test=0.529) total time=   1.3s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-11.678, test=-6777.595) R2: (train=0.997, test=0.519) total time=   1.4s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-11.582, test=-6798.669) R2: (train=0.997, test=0.520) total time=   1.3s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f83454a96c0>), regressor=DecisionTreeRegressor(); MSE: (train=-10.763, test=-7109.742) R2: (train=0.997, test=0.507) total time=   1.1s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=DecisionTreeRegressor(); MSE: (train=-11.276, test=-6879.673) R2: (train=0.997, test=0.519) total time=   1.3s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f26565936a0>), regressor=DecisionTreeRegressor(); MSE: (train=-12.347, test=-7143.585) R2: (train=0.997, test=0.513) total time=   1.2s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f8c8176f6a0>), regressor=DecisionTreeRegressor(); MSE: (train=-11.313, test=-7129.210) R2: (train=0.998, test=0.509) total time=   1.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2872.331, test=-4425.760) R2: (train=0.797, test=0.690) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2901.191, test=-4375.858) R2: (train=0.795, test=0.696) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2868.792, test=-4424.524) R2: (train=0.797, test=0.691) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2884.666, test=-4392.601) R2: (train=0.797, test=0.692) total time=   0.2s[CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2882.099, test=-4393.739) R2: (train=0.798, test=0.688) total time=   0.3s
#
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4821.955) R2: (train=1.000, test=0.658) total time=   0.2s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7ffa56b507c0>), regressor=DecisionTreeRegressor(); MSE: (train=-10.752, test=-7167.285) R2: (train=0.997, test=0.506) total time=   1.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4922.433) R2: (train=1.000, test=0.651) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4841.232) R2: (train=1.000, test=0.651) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4869.166) R2: (train=1.000, test=0.651) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4886.443) R2: (train=1.000, test=0.652) total time=   0.2s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f1c097776a0>), regressor=DecisionTreeRegressor(); MSE: (train=-9.884, test=-7064.308) R2: (train=0.997, test=0.511) total time=   1.5s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3061.206, test=-4343.426) R2: (train=0.785, test=0.699) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3061.352, test=-4339.803) R2: (train=0.786, test=0.693) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3038.481, test=-4362.018) R2: (train=0.786, test=0.696) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3054.840, test=-4330.155) R2: (train=0.786, test=0.697) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4767.147) R2: (train=1.000, test=0.663) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3044.903, test=-4359.587) R2: (train=0.786, test=0.696) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4772.849) R2: (train=1.000, test=0.656) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4847.403) R2: (train=1.000, test=0.657) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4798.494) R2: (train=1.000, test=0.657) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4815.279) R2: (train=1.000, test=0.658) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3201.214, test=-4320.609) R2: (train=0.776, test=0.702) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3191.514, test=-4307.832) R2: (train=0.777, test=0.700) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3186.026, test=-4343.937) R2: (train=0.777, test=0.698) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3199.984, test=-4306.135) R2: (train=0.777, test=0.695) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3186.621, test=-4352.029) R2: (train=0.777, test=0.698) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4722.200) R2: (train=1.000, test=0.660) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4726.992) R2: (train=1.000, test=0.667) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4801.949) R2: (train=1.000, test=0.660) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4754.374) R2: (train=1.000, test=0.661) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4776.892) R2: (train=1.000, test=0.662) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3321.603, test=-4323.291) R2: (train=0.768, test=0.703) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3321.153, test=-4310.250) R2: (train=0.770, test=0.696) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3306.502, test=-4336.360) R2: (train=0.770, test=0.700) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4701.733) R2: (train=1.000, test=0.669) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3302.543, test=-4340.063) R2: (train=0.770, test=0.700) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3309.202, test=-4310.574) R2: (train=0.769, test=0.700) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4699.007) R2: (train=1.000, test=0.662) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4773.087) R2: (train=1.000, test=0.663) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4724.799) R2: (train=1.000, test=0.664) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3420.529, test=-4340.246) R2: (train=0.762, test=0.704) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4743.018) R2: (train=1.000, test=0.665) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3405.279, test=-4351.233) R2: (train=0.763, test=0.700) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3422.616, test=-4308.897) R2: (train=0.764, test=0.697) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3407.507, test=-4329.774) R2: (train=0.763, test=0.701) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4691.967) R2: (train=1.000, test=0.671) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3413.165, test=-4321.843) R2: (train=0.763, test=0.701) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4674.685) R2: (train=1.000, test=0.664) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4755.223) R2: (train=1.000, test=0.665) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4704.827) R2: (train=1.000, test=0.666) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4719.324) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3507.585, test=-4333.210) R2: (train=0.757, test=0.705) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3512.539, test=-4319.767) R2: (train=0.758, test=0.697) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3495.206, test=-4362.518) R2: (train=0.758, test=0.700) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3497.936, test=-4337.261) R2: (train=0.758, test=0.702) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3501.831, test=-4327.184) R2: (train=0.758, test=0.701) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4670.890) R2: (train=1.000, test=0.673) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4741.343) R2: (train=1.000, test=0.666) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4683.798) R2: (train=1.000, test=0.668) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4658.275) R2: (train=1.000, test=0.666) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4703.397) R2: (train=1.000, test=0.668) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3586.698, test=-4348.015) R2: (train=0.752, test=0.705) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3576.331, test=-4383.151) R2: (train=0.753, test=0.699) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3587.908, test=-4339.725) R2: (train=0.753, test=0.697) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3586.620, test=-4345.507) R2: (train=0.753, test=0.701) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4648.645) R2: (train=1.000, test=0.667) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4660.929) R2: (train=1.000, test=0.674) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4730.655) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3582.778, test=-4354.195) R2: (train=0.753, test=0.702) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4670.097) R2: (train=1.000, test=0.669) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4693.087) R2: (train=1.000, test=0.670) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3662.373, test=-4365.027) R2: (train=0.749, test=0.696) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3663.991, test=-4374.956) R2: (train=0.747, test=0.704) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3648.548, test=-4411.136) R2: (train=0.749, test=0.699) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4640.407) R2: (train=1.000, test=0.668) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3658.855, test=-4365.799) R2: (train=0.749, test=0.700) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4655.252) R2: (train=1.000, test=0.675) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=uniform; MSE: (train=-3658.075, test=-4375.108) R2: (train=0.748, test=0.701) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4661.736) R2: (train=1.000, test=0.670) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4723.484) R2: (train=1.000, test=0.668) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=12, regressor__weights=distance; MSE: (train=-0.000, test=-4682.768) R2: (train=1.000, test=0.671) total time=   0.5s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3728.140, test=-4398.496) R2: (train=0.744, test=0.700) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3735.492, test=-4387.757) R2: (train=0.745, test=0.695) total time=   0.4s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3731.018, test=-4394.722) R2: (train=0.744, test=0.699) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3732.382, test=-4398.088) R2: (train=0.743, test=0.703) total time=   0.5s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=uniform; MSE: (train=-3719.220, test=-4427.366) R2: (train=0.745, test=0.698) total time=   0.4s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4646.681) R2: (train=1.000, test=0.676) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4635.021) R2: (train=1.000, test=0.669) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4716.242) R2: (train=1.000, test=0.669) total time=   0.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4655.876) R2: (train=1.000, test=0.670) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2900.471, test=-4376.455) R2: (train=0.795, test=0.696) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=KNeighborsRegressor(), regressor__n_neighbors=13, regressor__weights=distance; MSE: (train=-0.000, test=-4676.548) R2: (train=1.000, test=0.671) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2881.109, test=-4391.805) R2: (train=0.798, test=0.688) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2870.306, test=-4425.562) R2: (train=0.797, test=0.690) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2884.021, test=-4390.003) R2: (train=0.797, test=0.692) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=uniform; MSE: (train=-2868.411, test=-4421.621) R2: (train=0.797, test=0.691) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4840.670) R2: (train=1.000, test=0.651) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4922.729) R2: (train=1.000, test=0.651) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4821.681) R2: (train=1.000, test=0.659) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4864.814) R2: (train=1.000, test=0.652) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=5, regressor__weights=distance; MSE: (train=-0.000, test=-4883.908) R2: (train=1.000, test=0.652) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3060.321, test=-4338.752) R2: (train=0.786, test=0.693) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3060.305, test=-4343.459) R2: (train=0.785, test=0.699) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3037.362, test=-4360.290) R2: (train=0.786, test=0.696) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3053.916, test=-4328.435) R2: (train=0.786, test=0.697) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=uniform; MSE: (train=-3044.277, test=-4357.927) R2: (train=0.786, test=0.696) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4846.281) R2: (train=1.000, test=0.657) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4767.235) R2: (train=1.000, test=0.663) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4772.994) R2: (train=1.000, test=0.656) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4795.992) R2: (train=1.000, test=0.658) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=6, regressor__weights=distance; MSE: (train=-0.000, test=-4813.692) R2: (train=1.000, test=0.658) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3200.116, test=-4319.359) R2: (train=0.776, test=0.702) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3185.000, test=-4343.468) R2: (train=0.777, test=0.698) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3199.155, test=-4305.438) R2: (train=0.777, test=0.695) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3190.538, test=-4305.918) R2: (train=0.777, test=0.700) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4723.103) R2: (train=1.000, test=0.660) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=uniform; MSE: (train=-3185.556, test=-4350.263) R2: (train=0.777, test=0.698) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4726.261) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4801.775) R2: (train=1.000, test=0.660) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4775.639) R2: (train=1.000, test=0.662) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=7, regressor__weights=distance; MSE: (train=-0.000, test=-4751.421) R2: (train=1.000, test=0.661) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3321.110, test=-4322.835) R2: (train=0.768, test=0.703) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3319.880, test=-4310.393) R2: (train=0.770, test=0.696) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3305.678, test=-4335.924) R2: (train=0.770, test=0.700) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3301.900, test=-4339.829) R2: (train=0.770, test=0.700) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=uniform; MSE: (train=-3308.556, test=-4310.648) R2: (train=0.769, test=0.700) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4701.755) R2: (train=1.000, test=0.669) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4699.774) R2: (train=1.000, test=0.662) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4722.992) R2: (train=1.000, test=0.664) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4773.578) R2: (train=1.000, test=0.663) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=8, regressor__weights=distance; MSE: (train=-0.000, test=-4742.703) R2: (train=1.000, test=0.665) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3420.011, test=-4338.540) R2: (train=0.762, test=0.704) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3404.042, test=-4348.325) R2: (train=0.763, test=0.700) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3422.019, test=-4308.366) R2: (train=0.764, test=0.697) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3407.108, test=-4328.819) R2: (train=0.763, test=0.701) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4690.917) R2: (train=1.000, test=0.671) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=uniform; MSE: (train=-3411.848, test=-4320.866) R2: (train=0.763, test=0.701) total time=   0.3s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4675.022) R2: (train=1.000, test=0.664) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4754.668) R2: (train=1.000, test=0.665) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4702.487) R2: (train=1.000, test=0.666) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=9, regressor__weights=distance; MSE: (train=-0.000, test=-4718.723) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3511.451, test=-4318.374) R2: (train=0.758, test=0.698) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3506.916, test=-4331.947) R2: (train=0.757, test=0.705) total time=   0.3s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3494.649, test=-4362.265) R2: (train=0.758, test=0.700) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3497.055, test=-4336.659) R2: (train=0.758, test=0.702) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=uniform; MSE: (train=-3501.008, test=-4327.278) R2: (train=0.758, test=0.701) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4670.183) R2: (train=1.000, test=0.673) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4741.867) R2: (train=1.000, test=0.666) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4658.108) R2: (train=1.000, test=0.666) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4682.164) R2: (train=1.000, test=0.668) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3587.377, test=-4339.470) R2: (train=0.753, test=0.697) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=10, regressor__weights=distance; MSE: (train=-0.000, test=-4702.532) R2: (train=1.000, test=0.668) total time=   0.3s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3585.826, test=-4348.221) R2: (train=0.752, test=0.705) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3575.937, test=-4382.841) R2: (train=0.753, test=0.699) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3586.201, test=-4344.927) R2: (train=0.753, test=0.701) total time=   0.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=uniform; MSE: (train=-3582.286, test=-4352.857) R2: (train=0.753, test=0.702) total time=   0.2s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4648.684) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4661.146) R2: (train=1.000, test=0.674) total time=   0.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4731.224) R2: (train=1.000, test=0.667) total time=   0.2s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4668.118) R2: (train=1.000, test=0.669) total time=   0.3s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=KNeighborsRegressor(), regressor__n_neighbors=11, regressor__weights=distance; MSE: (train=-0.000, test=-4692.057) R2: (train=1.000, test=0.670) total time=   0.2s
# ...
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-767.859, test=-5004.523) R2: (train=0.945, test=0.647) total time=  12.2s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1057.619, test=-5246.028) R2: (train=0.925, test=0.637) total time=   4.0s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1057.069, test=-5270.297) R2: (train=0.925, test=0.628) total time=   3.8s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1036.846, test=-5345.526) R2: (train=0.926, test=0.629) total time=   3.9s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1042.729, test=-5293.829) R2: (train=0.926, test=0.630) total time=   3.7s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1041.209, test=-5359.641) R2: (train=0.926, test=0.626) total time=   3.7s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-704.586, test=-4970.447) R2: (train=0.949, test=0.648) total time=  31.5s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-708.749, test=-4939.802) R2: (train=0.949, test=0.657) total time=  31.7s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-708.539, test=-5011.649) R2: (train=0.949, test=0.650) total time=  31.7s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-757.575, test=-4912.540) R2: (train=0.946, test=0.659) total time=  17.1s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-753.556, test=-4957.351) R2: (train=0.946, test=0.650) total time=  17.2s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-752.698, test=-5018.269) R2: (train=0.946, test=0.650) total time=  16.5s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-707.793, test=-4999.344) R2: (train=0.949, test=0.648) total time=  31.1s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-708.657, test=-4944.952) R2: (train=0.949, test=0.651) total time=  31.4s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1074.807, test=-5334.943) R2: (train=0.923, test=0.630) total time=   3.2s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-750.211, test=-5013.764) R2: (train=0.946, test=0.649) total time=  15.1s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-755.586, test=-4981.243) R2: (train=0.946, test=0.651) total time=  15.7s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1068.701, test=-5337.254) R2: (train=0.924, test=0.624) total time=   3.1s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1067.039, test=-5367.359) R2: (train=0.924, test=0.623) total time=   2.9s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1065.740, test=-5398.246) R2: (train=0.924, test=0.624) total time=   3.4s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1058.788, test=-5412.620) R2: (train=0.925, test=0.621) total time=   3.3s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-768.449, test=-4984.227) R2: (train=0.945, test=0.654) total time=  11.6s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-768.221, test=-5006.285) R2: (train=0.945, test=0.645) total time=  11.7s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-764.204, test=-5057.608) R2: (train=0.945, test=0.647) total time=  12.6s
# [CV 1/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-702.211, test=-4838.456) R2: (train=0.949, test=0.664) total time=  37.7s
# [CV 2/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-697.612, test=-4882.786) R2: (train=0.950, test=0.654) total time=  39.1s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-760.859, test=-5054.569) R2: (train=0.945, test=0.645) total time=  11.3s
# [CV 4/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-696.524, test=-4884.873) R2: (train=0.950, test=0.656) total time=  39.6s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-764.942, test=-5035.630) R2: (train=0.945, test=0.645) total time=  12.7s
# [CV 3/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-697.924, test=-4923.634) R2: (train=0.950, test=0.657) total time=  41.1s
# [CV 5/5] END preprocessing=PCA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-693.499, test=-4937.198) R2: (train=0.950, test=0.654) total time=  37.6s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1051.343, test=-5268.748) R2: (train=0.925, test=0.632) total time=   4.1s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1002.636, test=-5126.457) R2: (train=0.928, test=0.636) total time=   4.2s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1022.561, test=-5153.335) R2: (train=0.927, test=0.637) total time=   4.5s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1025.282, test=-5149.429) R2: (train=0.927, test=0.636) total time=   4.1s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1006.556, test=-5240.752) R2: (train=0.928, test=0.630) total time=   4.3s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-709.949, test=-4917.176) R2: (train=0.949, test=0.658) total time=  30.7s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-738.360, test=-4787.248) R2: (train=0.946, test=0.665) total time=  16.4s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-734.234, test=-4827.418) R2: (train=0.947, test=0.655) total time=  16.7s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-731.663, test=-4850.447) R2: (train=0.947, test=0.659) total time=  16.0s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-705.718, test=-4940.014) R2: (train=0.949, test=0.649) total time=  31.2s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-703.362, test=-5003.348) R2: (train=0.949, test=0.651) total time=  30.3s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-704.599, test=-4989.970) R2: (train=0.949, test=0.649) total time=  30.2s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=2, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-706.532, test=-4944.250) R2: (train=0.949, test=0.651) total time=  31.5s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7ffa56b507c0>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1070.095, test=-5337.855) R2: (train=0.925, test=0.635) total time=   3.8s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-735.433, test=-4843.456) R2: (train=0.947, test=0.657) total time=  16.7s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7ffa56b507c0>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1058.772, test=-5298.206) R2: (train=0.926, test=0.629) total time=   3.8s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fc6c67127a0>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1054.336, test=-5413.049) R2: (train=0.926, test=0.627) total time=   4.4s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-731.672, test=-4873.789) R2: (train=0.947, test=0.656) total time=  16.5s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7ffa4e1fbce0>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1066.453, test=-5319.711) R2: (train=0.925, test=0.631) total time=   4.3s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fc6c67127a0>), regressor=RandomForestRegressor(), regressor__n_estimators=5; MSE: (train=-1056.006, test=-5389.334) R2: (train=0.926, test=0.626) total time=   4.1s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f1c097776a0>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-767.313, test=-5019.941) R2: (train=0.945, test=0.657) total time=  15.5s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7ffa4e1fbce0>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-762.948, test=-5005.278) R2: (train=0.946, test=0.648) total time=  16.4s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fc6c6738ae0>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-765.258, test=-5046.157) R2: (train=0.946, test=0.651) total time=  15.5s
# [CV 1/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-682.508, test=-4701.876) R2: (train=0.950, test=0.670) total time=  41.4s
# [CV 2/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-676.422, test=-4778.147) R2: (train=0.951, test=0.659) total time=  40.8s
# [CV 4/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-678.602, test=-4768.307) R2: (train=0.951, test=0.662) total time=  41.0s
# [CV 3/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-679.797, test=-4767.115) R2: (train=0.951, test=0.665) total time=  43.6s
# [CV 5/5] END preprocessing=FastICA(), preprocessing__n_components=3, regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-676.443, test=-4802.662) R2: (train=0.951, test=0.660) total time=  41.7s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f1c097776a0>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-767.830, test=-5016.842) R2: (train=0.946, test=0.651) total time=  16.9s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7ffa50e720c0>), regressor=RandomForestRegressor(), regressor__n_estimators=20; MSE: (train=-757.851, test=-5036.742) R2: (train=0.946, test=0.650) total time=  16.2s
# [CV 2/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f83425b7d80>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-706.551, test=-4926.107) R2: (train=0.950, test=0.653) total time=  28.8s
# [CV 5/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f264d73f600>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-703.781, test=-4985.020) R2: (train=0.950, test=0.654) total time=  26.8s
# [CV 4/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f8c8176f6a0>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-706.253, test=-4923.982) R2: (train=0.950, test=0.655) total time=  28.9s
# [CV 1/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7fc6c6738ae0>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-707.544, test=-4935.529) R2: (train=0.949, test=0.661) total time=  37.1s
# [CV 3/5] END preprocessing=FunctionTransformer(func=<function <lambda> at 0x7f8c5b5a76a0>), regressor=RandomForestRegressor(), regressor__n_estimators=50; MSE: (train=-704.853, test=-4953.769) R2: (train=0.950, test=0.657) total time=  35.2s
# GridSearchCV(estimator=Pipeline(steps=[('scaling', StandardScaler()),
#                                        ('preprocessing', 'passthrough'),
#                                        ('regressor', 'passthrough')]),
#              n_jobs=-1,
#              param_grid=[{'preprocessing': [PCA(), FastICA()],
#                           'preprocessing__n_components': [2, 3],
#                           'regressor': [LinearRegression(),
#                                         DecisionTreeRegressor()]},
#                          {'preprocessing': [FunctionTransformer(func=<function <lambda> at 0x7f42d...
#                           'regressor': [RandomForestRegressor()],
#                           'regressor__n_estimators': [5, 20, 50]},
#                          {'preprocessing': [FunctionTransformer(func=<function <lambda> at 0x7f42da667c40>)],
#                           'regressor': [RandomForestRegressor()],
#                           'regressor__n_estimators': [5, 20, 50]}],
#              refit='R2', return_train_score=True,
#              scoring={'MSE': make_scorer(mean_squared_error, greater_is_better=False),
#                       'R2': make_scorer(r2_score)},
#              verbose=4)

# %%
INVERSE_GRID.best_estimator_
# Out:
# Pipeline(steps=[('scaling', StandardScaler()),
#                 ('preprocessing', FastICA(n_components=3)),
#                 ('regressor', KNeighborsRegressor(n_neighbors=10))])

# %%
_, TRAIN_SAMPLES = train_test_split(TRAIN_DATA, test_size=200, random_state=13)
# TRAIN_SAMPLES=TRAIN_DATA

_, VALIDATION_SAMPLES = train_test_split(
    VALIDATION_DATA, test_size=200, random_state=13
)
# VALIDATION_SAMPLES=VALIDATION_DATA

# Draw graph with comparison of predicted vs AHM values for train and validation data
import matplotlib.pyplot as plt
import numpy as np

plt.figure(figsize=(10, 6), layout="constrained")

graph_angle = plt.subplot2grid((2, 2), (0, 0))
graph_angle.grid(True)
# graph_angle.set_xscale("log", nonpositive="clip")
# graph_angle.set_yscale("log", nonpositive="clip")

graph_ratio = plt.subplot2grid((2, 2), (0, 1))
# graph_ratio.grid(True)
# graph_ratio.set_xscale("log", nonpositive="clip")
# graph_ratio.set_yscale("log", nonpositive="clip")

graph_p_matrix = plt.subplot2grid((2, 2), (1, 0))
# graph_p_matrix.grid(True)
# graph_p_matrix.set_xscale("log", nonpositive="clip")
# graph_p_matrix.set_yscale("log", nonpositive="clip")

graph_p_fiber = plt.subplot2grid((2, 2), (1, 1))
# graph_p_fiber.grid(True)
# graph_p_fiber.set_xscale("log", nonpositive="clip")
# graph_p_fiber.set_yscale("log", nonpositive="clip")


x_train, y_train = (TRAIN_SAMPLES), (
    INVERSE_GRID.predict(TRAIN_SAMPLES[["p11", "p22", "p12"]])
)

x_validation, y_validation = (VALIDATION_SAMPLES), (
    INVERSE_GRID.predict(VALIDATION_SAMPLES[["p11", "p22", "p12"]])
)

graph_angle.scatter(
    x_train["angle"],
    y_train[:, 0],
    color="red",
    label="Datos de entrenamiento",
)
graph_angle.scatter(
    x_validation["angle"],
    y_validation[:, 0],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_angle.plot([40, 90], [40, 90], color="black")

# Limit x and y to the range between -40 and 10
graph_angle.set_xlim([40, 90])
graph_angle.set_ylim([40, 90])

graph_ratio.scatter(
    x_train["ratio"],
    y_train[:, 1],
    color="red",
    label="Datos de entrenamiento",
)
graph_ratio.scatter(
    x_validation["ratio"],
    y_validation[:, 1],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_ratio.plot([0.0, 0.7], [0.0, 0.7], color="black")

# Limit x and y to the range between 0 and 1000
graph_ratio.set_xlim([0, 0.7])
graph_ratio.set_ylim([0, 0.7])

graph_p_matrix.scatter(
    x_train["p_matrix"],
    y_train[:, 2],
    color="red",
    label="Datos de entrenamiento",
)
graph_p_matrix.scatter(
    x_validation["p_matrix"],
    y_validation[:, 2],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p_matrix.plot([0, 500], [0, 500], color="black")

# Limit x and y to the range between 0 and 1000
graph_p_matrix.set_xlim([0, 500])
graph_p_matrix.set_ylim([0, 500])

graph_p_fiber.scatter(
    x_train["p_fiber"],
    y_train[:, 3],
    color="red",
    label="Datos de entrenamiento",
)
graph_p_fiber.scatter(
    x_validation["p_fiber"],
    y_validation[:, 3],
    color="green",
    label="Datos de validación",
)

# Plot a line for the 1:1 relationship
graph_p_fiber.plot([0, 500], [0, 500], color="black")

# Limit x and y to the range between 0 and 1000
graph_p_fiber.set_xlim([0, 500])
graph_p_fiber.set_ylim([0, 500])


graph_angle.set_xlabel("Valores de homogenización")
graph_angle.set_ylabel("Valores estimados por KNN")
graph_angle.set_title("Valores estimados contra AHM para angle")

graph_ratio.set_xlabel("Valores de homogenización")
graph_ratio.set_ylabel("Valores estimados por KNN")
graph_ratio.set_title("Valores estimados contra AHM para ratio")

graph_p_matrix.set_xlabel("Valores de homogenización")
graph_p_matrix.set_ylabel("Valores estimados por KNN")
graph_p_matrix.set_title("Valores estimados contra AHM para p_matrix")

graph_p_fiber.set_xlabel("Valores de homogenización")
graph_p_fiber.set_ylabel("Valores estimados por KNN")
graph_p_fiber.set_title("Valores estimados contra AHM para p_fiber")

graph_angle.legend()
graph_ratio.legend()
graph_p_matrix.legend()
graph_p_fiber.legend()

plt.show()

# %%
[
    estimator.predict(TRAIN_DATA[["p11", "p22", "p12"]][69:70])
    for estimator in INVERSE_GRID.best_estimator_.steps[2][1].estimators_
]
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 [
#       2     estimator.predict(TRAIN_DATA[["p11", "p22", "p12"]][69:70])
# ----> 3     for estimator in INVERSE_GRID.best_estimator_.steps[2][1].estimators_
#       4 ]
#
# AttributeError: 'KNeighborsRegressor' object has no attribute 'estimators_'

# %%
import pandas as pd

rows = [v for k, v in GRID.cv_results_.items() if k.startswith("split") and "_test_" in k and k.endswith("R2")]

df=pd.DataFrame(
    [list(row) for row in zip(*rows)],
    columns=["split" + str(i) for i in range(5)],
    index=[get_pipe_name(pipe) for pipe in GRID.cv_results_["params"]],
    dtype=float
)

df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 3
#       1 import pandas as pd
# ----> 3 rows = [v for k, v in GRID.cv_results_.items() if k.startswith("split") and "_test_" in k and k.endswith("R2")]
#       5 df=pd.DataFrame(
#       6     [list(row) for row in zip(*rows)],
#       7     columns=["split" + str(i) for i in range(5)],
#       8     index=[get_pipe_name(pipe) for pipe in GRID.cv_results_["params"]],
#       9     dtype=float
#      10 )
#      12 df
#
# NameError: name 'GRID' is not defined

# %%
INVERSE_GRID.best_score_
# Out:
# 0.7099311079810912
